# %%
# !wget https://www.differencebetween.com/wp-content/uploads/2011/04/1024px-ISBN.jpg
# Out:
# --2023-11-30 02:16:04--  https://www.differencebetween.com/wp-content/uploads/2011/04/1024px-ISBN.jpg
# Resolving www.differencebetween.com (www.differencebetween.com)... 172.67.217.144, 104.21.75.79, 2606:4700:3034::ac43:d990, ...
# Connecting to www.differencebetween.com (www.differencebetween.com)|172.67.217.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 79365 (78K) [image/jpeg]
# Saving to: ‘1024px-ISBN.jpg’
#
# 1024px-ISBN.jpg     100%[===================>]  77.50K  --.-KB/s    in 0.03s
#
# 2023-11-30 02:16:04 (2.65 MB/s) - ‘1024px-ISBN.jpg’ saved [79365/79365]

# %%
# !pip install python-barcode[images]
# !pip install qrcode
# !apt install libzbar0
# !pip install pyzbar
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 3.9 MB/s eta 0:00:00
# ...
# ERROR: unknown command "installqrcode" - maybe you meant "install"
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts imagemagick-6-common
#   libdjvulibre-text libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libidn12 libijs-0.35
#   libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra
#   libmagickwand-6.q16-6 libv4l-0 libv4lconvert0 libwmflite-0.2-7 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x libfftw3-bin
#   libfftw3-dev inkscape poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum
# ...

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# define our imshow function

def imshow(title = "Image",image = None,size = 7):

  w,h = image.shape[0],image.shape[1]
  aspect_ratio = w/h
  plt.figure(figsize = (size*aspect_ratio,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

# %%
"""

Formats for bar code

EAN-8
EAN-13
EAN-14
UPC-A
CODE-39
CODE128
PZN

"""

# %%
from barcode import EAN13
from barcode.writer import ImageWriter


with open("barcode.png","wb") as f:
  EAN13("123456789102",writer = ImageWriter()).write(f)

barcode = cv2.imread("barcode.png")
imshow("Barcode",barcode)

# %%
#!pip install qrcode

import qrcode
from PIL import Image

qr = qrcode.QRCode(
    version = 1,
    error_correction = qrcode.constants.ERROR_CORRECT_H,
    box_size = 10,
    border = 4
)

qr.add_data("https://www.myntra.com/")
qr.make(fit=True)

image = qr.make_image(fill_color = "black", back_color = "white")
image.save("qrcode.png")

qrcode = cv2.imread("qrcode.png")
imshow("QR Code",qrcode,size = 8)

# %%
#!pip install qrcode

import qrcode
from PIL import Image

qr = qrcode.QRCode(
    version = 10,
    error_correction = qrcode.constants.ERROR_CORRECT_H,
    box_size = 10,
    border = 4
)

qr.add_data("https://www.google.com/maps/place/Unwind/@18.5387123,73.9102009,17z/data=!3m1!4b1!4m6!3m5!1s0x3bc2c174ca34cbef:0xc774013adb8fdd79!8m2!3d18.5387072!4d73.9127758!16s%2Fg%2F11g8dk84kq?entry=ttu")
qr.make(fit=True)

image = qr.make_image(fill_color = "black", back_color = "white")
image.save("unwind.png")

qrcode = cv2.imread("unwind.png")
imshow("QR Code",qrcode,size = 8)

# %%
#!pip install qrcode

import qrcode
from PIL import Image

qr = qrcode.QRCode(
    version = 10,
    error_correction = qrcode.constants.ERROR_CORRECT_H,
    box_size = 10,
    border = 4
)

qr.add_data("http://surl.li/nsnoh")
qr.make(fit=True)

image = qr.make_image(fill_color = "black", back_color = "white")
image.save("unwind_shorturl.png")

qrcode = cv2.imread("unwind_shorturl.png")
imshow("QR Code",qrcode,size = 8)

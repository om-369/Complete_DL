# %%
# Download and unzip our images and Haarcascade Classifiers
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# !wget https://moderncomputervision.s3.eu-west-2.amazonaws.com/haarcascades.zip

# !unzip -qq images.zip
# !unzip -qq haarcascades.zip
# Out:
# --2023-11-27 02:19:59--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/images.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 52.95.148.146, 3.5.245.156, 3.5.244.11, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|52.95.148.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29586716 (28M) [application/zip]
# Saving to: ‘images.zip’
#
# images.zip          100%[===================>]  28.22M  19.7MB/s    in 1.4s
#
# 2023-11-27 02:20:01 (19.7 MB/s) - ‘images.zip’ saved [29586716/29586716]
#
# --2023-11-27 02:20:01--  https://moderncomputervision.s3.eu-west-2.amazonaws.com/haarcascades.zip
# Resolving moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)... 52.95.148.146, 3.5.245.156, 3.5.244.11, ...
# Connecting to moderncomputervision.s3.eu-west-2.amazonaws.com (moderncomputervision.s3.eu-west-2.amazonaws.com)|52.95.148.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 276350 (270K) [application/zip]
# Saving to: ‘haarcascades.zip’
#
# haarcascades.zip    100%[===================>] 269.87K   707KB/s    in 0.4s
#
# 2023-11-27 02:20:02 (707 KB/s) - ‘haarcascades.zip’ saved [276350/276350]

# %%
#!https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
# define our imshow function

def imshow(title = "Image",image = None,size = 7):

  w,h = image.shape[0],image.shape[1]
  aspect_ratio = w/h
  plt.figure(figsize = (size*aspect_ratio,size))
  plt.imshow(cv2.cvtColor(image,cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")

image = cv2.imread("/content/images/Trump.jpg")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)

imshow("Face Detecction ",image)
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-12-acec150e0331>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")

image = cv2.imread("/content/ranbir_1.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)

imshow("Face Detecction ",image)
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-13-7d4f9f3493f9>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")

image = cv2.imread("/content/BIDEN2.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)

imshow("Face Detecction ",image)
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-14-a855eaea1f2a>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")

image = cv2.imread("/content/BIDEN1.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)

imshow("Face Detecction ",image)
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-15-fedb5d31f022>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")

image = cv2.imread("/content/blad.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)

imshow("Face Detecction ",image)
# Out:
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-16-fe196d6b5855>:11: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():
# No faces found

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_eye.xml")

image = cv2.imread("/content/ranbir_1.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
  roi_gray = gray[y:y+h,x:x+w]
  roi_color = image[y:y+h,x:x+w]
  eyes = eye_classifier.detectMultiScale(roi_gray,scaleFactor = 1.2,minNeighbors=3)
  for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)

imshow("Face Detecction & Eye Detection ",image)
# Out:
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-19-22157e0c2786>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_eye.xml")

image = cv2.imread("/content/BIDEN1.png")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
  roi_gray = gray[y:y+h,x:x+w]
  roi_color = image[y:y+h,x:x+w]
  eyes = eye_classifier.detectMultiScale(roi_gray,scaleFactor = 1.2,minNeighbors=3)
  for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)

imshow("Face Detecction & Eye Detection ",image)
# Out:
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-30-7c058378fb39>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
# we required xml files

face_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_frontalface_default.xml")
eye_classifier = cv2.CascadeClassifier("/content/Haarcascades/haarcascade_eye.xml")

image = cv2.imread("/content/images/Trump.jpg")
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

faces = face_classifier.detectMultiScale(gray,scaleFactor = 1.3,minNeighbors=5)


if faces is ():
  print("No faces found")

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(127,0,255),2)
  roi_gray = gray[y:y+h,x:x+w]
  roi_color = image[y:y+h,x:x+w]
  eyes = eye_classifier.detectMultiScale(roi_gray,scaleFactor = 1.2,minNeighbors=3)
  for (ex,ey,ew,eh) in eyes:
    cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)

imshow("Face Detecction & Eye Detection ",image)
# Out:
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <ipython-input-29-2d6d9080539a>:12: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if faces is ():

# %%
#Different Transformers Architecture :

# %%
from IPython.display import Image, display

# %%
display(Image("/content/transformers_model_tree.jpeg"))

# %%
#Encoder only

understanding input

sentiment analysis, text classifiaction, ner

Models : BERT, Distill BERT, RoBERTa

#fine tuning needed for down stream task

# %%
#Encoder-Decoder

understanding and generation

machine translation, text summarization, Image captioing, speech to text


Models : T5,

# %%
#Decoder only

generation

creating writing, good at generating text


Model : GPT 1, 2,3,3.5,4, J, neo ,      llama1, 2,   PaLM

# %%
#Artificial shallow intelligence

#Artificial general intelligence

#Artificial super intelligence

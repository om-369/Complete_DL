# %% [markdown]
# ## NEURAL NETWORK REGRESSION

# %%
"""

SELLING OF AN HOUSE PRICE
DEMAND /SUPPLY / LOGISTICS
COST OF MEDICAL INSURANCE
CORDINATES OF AN IMAGE

"""
# Out:
# '\n\nSELLING OF AN HOUSE PRICE\nDEMAND /SUPPLY / LOGISTICS\nCOST OF MEDICAL INSURANCE\nCORDINATES OF AN IMAGE\n\n'

# %%
"""

INPUT SHAPE
  X FEATURES : DATA SET
  Y FEATURE : DATASET TARGET VARIABLE

CREATING THE CUSTOM MODEL

STEPS IN MODELLING :
  1. CREATE MODEL
  2. COMPILE THE MODEL
    A. DEFINING LOSS FUNCTION.
    B. OPTIMIZER
    C. EVALUATION METRICS
  3. FITTING THE MODEL ( FINDING THE PATTERNS IN DATS SET)
  4. EVALUATE THE RESULTS FROM MODEL
  5. SAVE THE MODEL
  6. LOAD THE MODEL


"""
# Out:
# '\n\nINPUT SHAPE\n  X FEATURES : DATA SET\n  Y FEATURE : DATASET TARGET VARIABLE\n\nCREATING THE CUSTOM MODEL\n\nSTEPS IN MODELLING :\n  1. CREATE MODEL\n  2. COMPILE THE MODEL\n    A. DEFINING LOSS FUNCTION.\n    B. OPTIMIZER\n    C. EVALUATION METRICS\n  3. FITTING THE MODEL ( FINDING THE PATTERNS IN DATS SET)\n  4. EVALUATE THE RESULTS FROM MODEL\n  5. SAVE THE MODEL\n  6. LOAD THE MODEL\n\n\n'

# %%
"""

NEURONS PER HIDDEN LAYER : PROBLEM SPECIFIC RANGING FROM 10 TO 100

LOSS FUNCTION : MSE/MAE/HUBER

"""
# Out:
# '\n\nNEURONS PER HIDDEN LAYER : PROBLEM SPECIFIC RANGING FROM 10 TO 100\n\nLOSS FUNCTION : MSE/MAE/HUBER\n\n'

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([-7,-4,-1,2,5,8,11,14])

x
# Out:
# array([-7, -4, -1,  2,  5,  8, 11, 14])

# %%
y = x + 10

# %%
x,y
# Out:
# (array([-7, -4, -1,  2,  5,  8, 11, 14]),
#  array([ 3,  6,  9, 12, 15, 18, 21, 24]))

# %%
plt.scatter(x,y)

# %%
x[0],y[0]
# Out:
# (-7, 3)

# %%
input_shape = x[0].shape

output_shape = y[0].shape

# %%
input_shape,output_shape
# Out:
# ((), ())

# %%
# create the model using sequential api

model = tf.keras.Sequential([
          tf.keras.layers.Dense(1)
])

#compiling the model
model.compile(
            loss = tf.keras.losses.mae,  # mean absolute error
            optimizer = tf.keras.optimizers.SGD(), # STOCHASTIC GRADIENT DESCENT
            metrics = ["mae"]
)

# fit the model
model.fit(tf.expand_dims(x,axis=-1),
          y,
          epochs= 5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 0s 412ms/step - loss: 19.3116 - mae: 19.3116
# Epoch 2/5
# 1/1 [==============================] - 0s 7ms/step - loss: 19.0304 - mae: 19.0304
# Epoch 3/5
# 1/1 [==============================] - 0s 8ms/step - loss: 18.7491 - mae: 18.7491
# Epoch 4/5
# 1/1 [==============================] - 0s 21ms/step - loss: 18.4679 - mae: 18.4679
# Epoch 5/5
# 1/1 [==============================] - 0s 14ms/step - loss: 18.1866 - mae: 18.1866

# %%
# lets have the prediction of model created

model.predict([17])
# Out:
# 1/1 [==============================] - 0s 99ms/step
# array([[-21.729057]], dtype=float32)

# %% [markdown]
# ## Improve the Deep Learning Model

# %%
"""

Adding the layers
increase the number of neurons in hidden layers
change activation functions
change the optimization function
change the learning rate
fitting on more data
fitting for longer time period

"""

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_2.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae"])

model_2.fit(tf.expand_dims(x,axis=-1),y,epochs = 100 )
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 220ms/step - loss: 13.2833 - mae: 13.2833
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.1508 - mae: 13.1508
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.0183 - mae: 13.0183
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.8858 - mae: 12.8858
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.7533 - mae: 12.7533
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.6208 - mae: 12.6208
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 12.4883 - mae: 12.4883
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.3558 - mae: 12.3558
# Epoch 9/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.2233 - mae: 12.2233
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.0908 - mae: 12.0908
# Epoch 11/100
# ...

# %%
x,y
# Out:
# (array([-7, -4, -1,  2,  5,  8, 11, 14]),
#  array([ 3,  6,  9, 12, 15, 18, 21, 24]))

# %%
model_2.predict([17])    # expected result 27
# Out:
# 1/1 [==============================] - 0s 45ms/step
# array([[29.88499]], dtype=float32)

# %%
model_2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
x = np.arange(-100,100,4)

x
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
len(x)
# Out:
# 50

# %%
y = x+10

# %%
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# split the dataset

# train data
x_train = x[:40]
y_train = y[:40]

# test data
x_test = x[40:]
y_test = y[40:]

# %%
plt.scatter(x,y)

# %%
plt.scatter(x_train,y_train,c='b',label = "Training Data")
plt.scatter(x_test,y_test,c='r',label = 'Testing Data')
plt.legend();

# %%
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_2.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.SGD(),
              metrics = ["mae"])

model_2.fit(tf.expand_dims(x,axis=-1),y,epochs = 100 )
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 8ms/step - loss: 29.7234 - mae: 29.7234
# Epoch 2/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.2651 - mae: 10.2651
# Epoch 3/100
# 2/2 [==============================] - 0s 5ms/step - loss: 11.4200 - mae: 11.4200
# Epoch 4/100
# 2/2 [==============================] - 0s 5ms/step - loss: 9.8341 - mae: 9.8341
# Epoch 5/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.8258 - mae: 9.8258
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.7318 - mae: 10.7318
# Epoch 7/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.6564 - mae: 10.6564
# Epoch 8/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.0451 - mae: 10.0451
# Epoch 9/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.0238 - mae: 10.0238
# Epoch 10/100
# 2/2 [==============================] - 0s 8ms/step - loss: 9.7860 - mae: 9.7860
# Epoch 11/100
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_2,show_shapes = True)

# %%
model_2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 1)                 2
#
# ...
# Total params: 2 (8.00 Byte)
# Trainable params: 2 (8.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
y_pred = model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
y_pred
# Out:
# array([[ -76.77931 ],
#        [ -81.90027 ],
#        [ -87.021225],
#        [ -92.14218 ],
#        [ -97.26313 ],
#        [-102.38409 ],
#        [-107.50504 ],
#        [-112.62599 ],
#        [-117.74695 ],
#        [-122.867905]], dtype=float32)

# %%
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model_3.compile(loss = tf.keras.losses.mae,
              optimizer = tf.keras.optimizers.Adam(),
              metrics = ["mae"])

model_3.fit(tf.expand_dims(x,axis=-1),y,epochs = 100 )
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.5810 - mae: 10.5810
# Epoch 2/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.5453 - mae: 10.5453
# Epoch 3/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.5015 - mae: 10.5015
# Epoch 4/100
# 2/2 [==============================] - 0s 4ms/step - loss: 10.4636 - mae: 10.4636
# Epoch 5/100
# 2/2 [==============================] - 0s 7ms/step - loss: 10.4220 - mae: 10.4220
# Epoch 6/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.3976 - mae: 10.3976
# Epoch 7/100
# 2/2 [==============================] - 0s 5ms/step - loss: 10.3609 - mae: 10.3609
# Epoch 8/100
# 2/2 [==============================] - 0s 4ms/step - loss: 10.3418 - mae: 10.3418
# Epoch 9/100
# 2/2 [==============================] - 0s 7ms/step - loss: 10.3156 - mae: 10.3156
# Epoch 10/100
# 2/2 [==============================] - 0s 6ms/step - loss: 10.2926 - mae: 10.2926
# Epoch 11/100
# ...

# %%
y_pred_2 = model_3.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 62ms/step

# %%
y_pred
# Out:
# array([[ -76.77931 ],
#        [ -81.90027 ],
#        [ -87.021225],
#        [ -92.14218 ],
#        [ -97.26313 ],
#        [-102.38409 ],
#        [-107.50504 ],
#        [-112.62599 ],
#        [-117.74695 ],
#        [-122.867905]], dtype=float32)

# %%
y_pred_2
# Out:
# array([[ 64.68836 ],
#        [ 68.987114],
#        [ 73.285866],
#        [ 77.58462 ],
#        [ 81.88337 ],
#        [ 86.18212 ],
#        [ 90.48088 ],
#        [ 94.77963 ],
#        [ 99.078384],
#        [103.37714 ]], dtype=float32)

# %%
x_test
# Out:
# array([60, 64, 68, 72, 76, 80, 84, 88, 92, 96])

# %%
y_test
# Out:
# array([ 70,  74,  78,  82,  86,  90,  94,  98, 102, 106])
